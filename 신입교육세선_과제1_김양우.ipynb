# %% [markdown]
# [2022월드컵 데이터 출처] (https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results?resource=download)

# %%
선정 이유: 평소에 축구를 즐겨 보며 특히 2022년 월드컵은 굉장히 재밌게 봤던 월드컵이었기에 관련 데이터를 보고 싶었다.
특징: 모든 경기의 패스 횟수, 스코어와 같은 세부 지표들이 모두 기재되어 있다.
